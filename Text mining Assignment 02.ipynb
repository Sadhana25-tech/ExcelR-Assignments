# %%
import requests 
import pandas as pd
from bs4 import BeautifulSoup

# %%
 TWO:
1) Extract reviews of any product from ecommerce website like amazon
2) Perform emotion mining
# Out:
#   File "<ipython-input-2-939f07da10e2>", line 1
#     TWO:
#         ^
# SyntaxError: invalid syntax

# %%
url='https://www.amazon.in/product-reviews/B07HGLBZ5R/ref=cm_cr_arp_d_viewopt_sr?ie=UTF8&filterByStar=all_stars&reviewerType=all_reviews&pageNumber=1#reviews-filter-bar'

# %%
review_html = requests.get(url)

# %%
review_html = review_html.text

# %%
review_html
# Out:
# '<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n\n<!-- sp:feature:aui-assets -->\n<link rel="stylesheet" href="https://images-eu.ssl-images-amazon.com/images/I/11EIQ5IGqaL._RC|01ZTHTZObnL.css,41+dLWMMeXL.css,21qPwhPKAAL.css,01Vctty9pOL.css,017DsKjNQJL.css,0131vqwP5UL.css,41EWOOlBJ9L.css,11TIuySqr6L.css,01ElnPiDxWL.css,11bGSgD5pDL.css,01Dm5eKVxwL.css,01IdKcBuAdL.css,01y-XAlI+2L.css,01ZfXnjPmmL.css,01oDR3IULNL.css,31q1y1irc5L.css,01XPHJk60-L.css,01R0k0yxPXL.css,21xVR0NtxzL.css,11gneA3MtJL.css,21fecG8pUzL.css,01RddH8vm-L.css,01CFUgsA-YL.css,21AmhU6t0
# ...

# %%
soup = BeautifulSoup(review_html, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:feature:aui-assets -->
# ...

# %%
review_titles = soup.findAll('a', {'data-hook':'review-title','class': 'a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold'})
review_titles
# Out:
# [<a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R2X5AXUCM166BC?ASIN=B07HGLBZ5R">
#  <span>"My phone isn't responding"</span>
#  </a>,
#  <a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/RR6WYS9TAZQ09?ASIN=B07HGLBZ5R">
#  <span>Disappointed with the quality</span>
#  </a>,
#  <a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/RIB81K2JQVX9R?ASIN=B07HGLBZ5R">
#  <span>Really disappointed</span>
#  </a>,
#  <a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/RNDNE4KPOYNS5?ASIN=B07HGLBZ5R">
#  <span>Bang for the bucks.</span>
#  </a>,
# ...

# %%
len( review_titles )
# Out:
# 10

# %%
title = review_titles[1]
title.text
# Out:
# '\nDisappointed with the quality\n'

# %%
titles = []
for review_title in review_titles:
    titles.append( review_title.text )
titles = pd.Series(titles,name="ReviewTitle")
titles
# Out:
# 0                    \n"My phone isn't responding"\n
# 1                  \nDisappointed with the quality\n
# 2                            \nReally disappointed\n
# 3                            \nBang for the bucks.\n
# 4                                \n*True flagship*\n
# 5                                 \nWaste of money\n
# 6                                  \nHanging issue\n
# 7                            \nOver hiped device!!\n
# 8                \nThumbprint scanner malfunction?\n
# 9    \nIt pains me to give oneplus a 1 star rating\n
# Name: ReviewTitle, dtype: object

# %%
review_dates = soup.findAll('span',{"data-hook":"review-date","class":"a-size-base a-color-secondary review-date"})
review_dates
# Out:
# [<span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India on 19 May 2019</span>,
#  <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India on 22 May 2019</span>,
#  <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India on 19 May 2019</span>,
#  <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India on 19 May 2019</span>,
#  <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India on 19 May 2019</span>,
#  <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India on 19 May 2019</span>,
#  <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India on 19 May 2019</span>,
#  <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India on 19 May 2019</span>,
# ...

# %%
date = []
for ele in review_dates:
    date.append(ele.text)
date = pd.Series(date, name = "review_date")
date
# Out:
# 0    Reviewed in India on 19 May 2019
# 1    Reviewed in India on 22 May 2019
# 2    Reviewed in India on 19 May 2019
# 3    Reviewed in India on 19 May 2019
# 4    Reviewed in India on 19 May 2019
# 5    Reviewed in India on 19 May 2019
# 6    Reviewed in India on 19 May 2019
# 7    Reviewed in India on 19 May 2019
# 8    Reviewed in India on 19 May 2019
# 9    Reviewed in India on 19 May 2019
# Name: review_date, dtype: object

# %%
review_texts = soup.findAll('span', {'class': 'a-size-base review-text review-text-content'})
len( review_texts )
# Out:
# 10

# %%
review_texts
# Out:
# [<span class="a-size-base review-text review-text-content" data-hook="review-body">
#  <span>
#    The same thing happening in the new replaced phone also I feel disappointed it's not worth for the money. It's hanging a lot in phone application. I am getting irritated when I am try to make a call. I need to wait for 30 to 40 seconds in that to most of the time it closing automatically showing phone is not responding. I didn't expect this from one plus. Totally waste product...
#  </span>
#  </span>,
#  <span class="a-size-base review-text review-text-content" data-hook="review-body"><div class="a-section a-spacing-small a-spacing-top-mini video-block" id="video-block-RR6WYS9TAZQ09">
#  <video class="cr-video-desktop" controls="" id="review-video-id-RR6WYS9TAZQ09" poster="https://images-eu.ssl-images-amazon.com/images/I/717KhKp09FS._SL256.png" preload="none">
#  <source src="https://images-eu.ssl-images-amazon.com/images/I/B1JsVYOHa3S.mp4" type="video/mp4">
# ...

# %%
text = []
for review_text in review_texts:
    text.append( review_text.text )
text = pd.Series(text,name="ReviewText")

# %%
import re
r_texts = list( map( lambda x: re.sub("[^a-zA-Z]", " ", x.text ), review_texts ) )

# %%
r_titles = list( map( lambda x: re.sub("[^a-zA-Z]", " ", x.text ), review_titles ) )

# %%
import pandas as pd
review_df = pd.DataFrame( { "title": r_titles, "text": r_texts } )

# %%
review_df
# Out:
#                                            title  \
# 0                    My phone isn t responding
# 1                 Disappointed with the quality
# 2                           Really disappointed
# 3                           Bang for the bucks
# 4                                True flagship
# 5                                Waste of money
# 6                                 Hanging issue
# 7                           Over hiped device
# 8               Thumbprint scanner malfunction
# 9   It pains me to give oneplus a   star rating
#
#                                                 text
# 0      The same thing happening in the new replac...
# 1       Your browser does not support HTML  video...
# 2      Everything is best except the thing that o...
# 3      Awesome device  and hats off to amazon for...
# 4      Worth every buck Finally one plus has invo...
# 5      Waste of money this time one plus   pro he...
# 6      This phone has a hanging issue  Nd ur cust...
# ...

# %%
review_df1 = review_df.rename(columns={'text':'x'})

# %%
review_df1
# Out:
#                                            title  \
# 0                    My phone isn t responding
# 1                 Disappointed with the quality
# 2                           Really disappointed
# 3                           Bang for the bucks
# 4                                True flagship
# 5                                Waste of money
# 6                                 Hanging issue
# 7                           Over hiped device
# 8               Thumbprint scanner malfunction
# 9   It pains me to give oneplus a   star rating
#
#                                                    x
# 0      The same thing happening in the new replac...
# 1       Your browser does not support HTML  video...
# 2      Everything is best except the thing that o...
# 3      Awesome device  and hats off to amazon for...
# 4      Worth every buck Finally one plus has invo...
# 5      Waste of money this time one plus   pro he...
# 6      This phone has a hanging issue  Nd ur cust...
# ...

# %%
pip install ipykernel
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install spacy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import string # special operations on strings
import spacy
from matplotlib.pyplot import imread
from matplotlib import pyplot as plt
from wordcloud import WordCloud
# %matplotlib inline

# %%
review_df1 = [x.strip() for x in review_df1.x]

# %%
review_df1

# %%
review_df1 = [x for x in review_df1 if x] # removes empty strings, because they are considered in Python as False

# %%
review_df1

# %%
nlp = spacy.load('en_core_web_sm')

# %%
one_block = review_df1[9]
doc_block = nlp(one_block)
spacy.displacy.render(doc_block, style='ent', jupyter=True)

# %%
one_block

# %%
for token in doc_block[0:9]:
    print(token, token.pos_)

# %%
nouns_verbs = [token.text for token in doc_block if token.pos_ in ('NOUN', 'VERB')]
print(nouns_verbs[5:25])

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()

X = cv.fit_transform(nouns_verbs)
sum_words = X.sum(axis=0)
words_freq = [(word, sum_words[0, idx]) for word, idx in cv.vocabulary_.items()]
words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
wf_df = pd.DataFrame(words_freq)
wf_df.columns = ['word', 'count']

wf_df[0:10]

# %%
##Visualizing results
#Barchart for top 10 nouns + verbs
wf_df[0:10].plot.bar(x='word', figsize=(12,8), title='Top verbs and nouns')

# %%
#Sentiment analysis
afinn = pd.read_csv('Afinn.csv', sep=',', encoding='latin-1')
afinn.shape

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import string # special operations on strings
import spacy # language models

from matplotlib.pyplot import imread
from matplotlib import pyplot as plt
from wordcloud import WordCloud
# %matplotlib inline

# %%
review_df1

# %%
review_df

# %%
review_df.drop('title', inplace=True, axis=1)

# %%
review_df

# %%
book = review_df.rename(columns={'text':'x'})

# %%
book = [x.strip() for x in book.x] # remove both the leading and the trailing characters
book = [x for x in book if x] # removes empty strings, because they are considered in Python as False

# %%
book

# %%
pip install spacy

# %%
import nltk
nltk.download('punkt')

# %%
from nltk.tokenize import sent_tokenize

# %%
sentences = tokenize.sent_tokenize(" ".join(book))

# %%
sentences

# %%
affinity_scores = afinn.set_index('word')['value'].to_dict()

# %%
nlp = spacy.load('en_core_web_sm')
sentiment_lexicon = affinity_scores

def calculate_sentiment(text: str = None):
    sent_score = 0
    if text:
        sentence = nlp(text)
        for word in sentence:
            sent_score += sentiment_lexicon.get(word.lemma_, 0)
    return sent_score

# %%
calculate_sentiment(text = 'amazing')

# %%
sent_df['sentiment_value'] = sent_df['kk'].apply(calculate_sentiment)

# %%
sent_df['word_count'] = sent_df['kk'].str.split().apply(len)
sent_df['word_count'].head(10)

# %%
sent_df
